# %%
using QuantumStates
using UnitsToValue

# %%
# Define the operator for the Hamiltonian
H_operator = :(
    T * DiagonalOperator +
    B_Σ * Rotation_Σ +
    B_Δ * Rotation_Δ +
    A_v * SpinOrbit + 
    q_e * (ΛDoubling_q + 2ΛDoubling_p2q) +
    p_e * ΛDoubling_p2q +
    q_v * ℓDoubling + 
    ϵω2 * (RennerTeller/2) +
    s * basis_splitting #+
    # b00_A * Hyperfine_IF
    # b00_A * Hyperfine_IL
    # b00_A * (Hyperfine_IF - Hyperfine_IL)
);

# %%
# Spectroscopic parameters for the A(010) state from Li & Coxon (1995)
# Note that parameters are converted from cm⁻¹ to Hz
parameters = @params begin
    T = 16360.389 * c * 1e2
    B_Σ = 0.3402123 * c * 1e2
    B_Δ = 0.3402609 * c * 1e2
    A_v = 67.0951 * c * 1e2
    q_e = -0.3072e-3 * c * 1e2
    p_e = -0.04472 * c * 1e2
    q_v = -0.6978e-3 * c * 1e2
    ϵω2 = -36.2634 * c * 1e2
    b00_A = 1e6
    s = 0.
end;

# %%
# Define bounds for the quantum numbers that define which states to include in the basis
QN_bounds = (
    label = "A",
    v_1 = 0,
    v_2 = 1,
    ℓ = (-1,1),
    v_3 = 0,
    Λ = (-1,1),
    I = 1/2,
    S = 1/2,
    J = 1/2:11/2
    # J = 1/2:5/2
    )
basis = enumerate_states(HundsCaseA_LinearMolecule, QN_bounds)
;

# %%
CaOH_A010 = @time Hamiltonian(basis=basis, operator=H_operator, parameters=parameters)
@time full_evaluate!(CaOH_A010)
@time solve!(CaOH_A010)
;
# Out:
#   6.279020 seconds (77.80 M allocations: 2.571 GiB, 17.18% gc time)
#   5.617328 seconds (77.80 M allocations: 2.436 GiB, 15.13% gc time)
#   0.527984 seconds (3.09 k allocations: 25.624 MiB)

# %%
using Plots
hline(energy.(CaOH_A010.states))
# plot!(ylim=(16290, 16425))

# %%
@time save_to_file(CaOH_A010, "CaOH_A010", "")
# Out:
#   0.067958 seconds (63.86 k allocations: 1.334 MiB)
