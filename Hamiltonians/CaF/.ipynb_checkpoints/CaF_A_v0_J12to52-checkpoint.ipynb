# %%
using QuantumStates

# %% [markdown]
# The Hamiltonian is assumed to take the following form:
# $$
# H(A^2\Pi) = T + A \Lambda \Sigma + BN^2 - DN^4 + \frac{1}{2} (p + 2q)(e^{2i\phi} S_- J_- + e^{-2i\phi} S_+ J_+) - \frac{1}{2} q (e^{2i\phi} J_-^2 + e^{-2i\phi} J_+^2).
# $$
# These terms correspond to the origin, spin-orbit, rotation and centrifugal distortion correction, and $\Lambda$-doubling terms.

# %%
H_operator = :(
    T_A * DiagonalOperator +
    Be_A * Rotation + 
    Aso_A * SpinOrbit + 
    q_A * (ΛDoubling_q + 2ΛDoubling_p2q) +
    p_A * ΛDoubling_p2q + 
    # B_z * Zeeman_L +
    # b00_A * Hyperfine_IL +
    # b00_A * Hyperfine_IF +
    b00_A * (Hyperfine_IF - Hyperfine_IL) +
    s * basis_splitting
);

# %%
# Spectroscopic constants for the A²Π state in CaF (from Eunmi Chae's thesis, 2016)
parameters = @params begin
    T_A = 16526.750 * c * 1e2
    Be_A = 0.348781 * c * 1e2
    Aso_A = 71.429 * c * 1e2
    b00_A = 1e6
    p_A = -0.044517 * c * 1e2
    q_A = -2.916e-4 * c * 1e2
    B_z = 0.
    s = 1e6
end;

# %%
QN_bounds = (label = "A", S = 1/2, I = 1/2, Λ = (-1,1), J = 1/2:9/2)
basis = enumerate_states(HundsCaseA_LinearMolecule, QN_bounds)
;

# %%
CaF_A_v0 = @time Hamiltonian(basis=basis, operator=H_operator, parameters=parameters)
@time full_evaluate!(CaF_A_v0)
@time solve!(CaF_A_v0)
;
# Out:
#   0.413425 seconds (6.29 M allocations: 216.065 MiB, 17.87% gc time)
#   0.417888 seconds (6.29 M allocations: 199.593 MiB, 17.16% gc time)
#   0.037198 seconds (944 allocations: 3.509 MiB)

# %%
@time save_to_file(CaF_A_v0, "CaF_A_v0", "")
# Out:
#   0.010861 seconds (22.93 k allocations: 485.648 KiB)

# %%
using Plots

# %%
energy.(CaF_A_v0.states[1:120]) |> hline

# %%
CaF_A_v0.states[25]
# Out:
# State{HundsCaseA_LinearMolecule}(4.944804702922371e14, HundsCaseA_LinearMolecule[HundsCaseA_LinearMolecule(0.0, "A", 0, 0, 0, 0, -1, -1, 1/2, 1/2, -1/2, 3/2, -3/2, 1, -1, (K = -1, Σ = -0.5:1.0:0.5, P = -1.5:1.0:-1.5, F = 1.0:1.0:2.0, M = -1.0:1.0:1.0)), HundsCaseA_LinearMolecule(0.0, "A", 0, 0, 0, 0, -1, -1, 1/2, 1/2, -1/2, 3/2, -3/2, 1, 0, (K = -1, Σ = -0.5:1.0:0.5, P = -1.5:1.0:-1.5, F = 1.0:1.0:2.0, M = -1.0:1.0:1.0)), HundsCaseA_LinearMolecule(0.0, "A", 0, 0, 0, 0, -1, -1, 1/2, 1/2, -1/2, 3/2, -3/2, 1, 1, (K = -1, Σ = -0.5:1.0:0.5, P = -1.5:1.0:-1.5, F = 1.0:1.0:2.0, M = -1.0:1.0:1.0)), HundsCaseA_LinearMolecule(0.0, "A", 0, 0, 0, 0, -1, -1, 1/2, 1/2, -1/2, 3/2, -3/2, 2, -2, (K = -1, Σ = -0.5:1.0:0.5, P = -1.5:1.0:-1.5, F = 1.0:1.0:2.0, M = -2.0:1.0:2.0)), HundsCaseA_LinearMolecule(0.0, "A", 0, 0, 0, 0, -1, -1, 1/2, 1/2, -1/2, 3/2, -3/2, 2, -1, (K = -1, Σ = -0.5:1.0:0.5, P = -1.5:1.0:-1.5, F = 1.0:1.0:2.0, M = -2.0:1.0:2.0)), HundsCaseA_LinearMolecule(0.0, "A", 0, 0, 0, 0, -1, -1, 1/2, 1/2, -1/2, 3/2, -3/2, 2, 0, (K = -1, Σ = -0.5:1.0:0.5, P = -1.5:1.0:-1.5, F = 1.0:1.0:2.0, M = -2.0:1.0:2.0)), HundsCaseA_LinearMolecule(0.0, "A", 0, 0, 0, 0, -1, -1, 1/2, 1/2, -1/2, 3/2, -3/2, 2, 1, (K = -1, Σ = -0.5:1.0:0.5, P = -1.5:1.0:-1.5, F = 1.0:1.0:2.0, M = -2.0:1.0:2.0)), HundsCaseA_LinearMolecule(0.0, "A", 0, 0, 0, 0, -1, -1, 1/2, 1/2, -1/2, 3/2, -3/2, 2, 2, (K = -1, Σ = -0.5:1.0:0.5, P = -1.5:1.0:-1.5, F = 1.0:1.0:2.0, M = -2.0:1.0:2.0)), HundsCaseA_LinearMolecule(0.0, "A", 0, 0, 0, 0, -1, -1, 1/2, 1/2, -1/2, 5/2, -3/2, 2, -2, (K = -1, Σ = -0.5:1.0:0.5, P = -1.5:1.0:-1.5, F = 2.0:1.0:3.0, M = -2.0:1.0:2.0)), HundsCaseA_LinearMolecule(0.0, "A", 0, 0, 0, 0, -1, -1, 1/2, 1/2, -1/2, 5/2, -3/2, 2, -1, (K = -1, Σ = -0.5:1.0:0.5, P = -1.5:1.0:-1.5, F = 2.0:1.0:3.0, M = -2.0:1.0:2.0))  …  HundsCaseA_LinearMolecule(0.0, "A", 0, 0, 0, 0, 1, 1, 1/2, 1/2, 1/2, 9/2, 3/2, 5, -4, (K = 1, Σ = -0.5:1.0:0.5, P = 1.5:1.0:1.5, F = 4.0:1.0:5.0, M = -5.0:1.0:5.0)), HundsCaseA_LinearMolecule(0.0, "A", 0, 0, 0, 0, 1, 1, 1/2, 1/2, 1/2, 9/2, 3/2, 5, -3, (K = 1, Σ = -0.5:1.0:0.5, P = 1.5:1.0:1.5, F = 4.0:1.0:5.0, M = -5.0:1.0:5.0)), HundsCaseA_LinearMolecule(0.0, "A", 0, 0, 0, 0, 1, 1, 1/2, 1/2, 1/2, 9/2, 3/2, 5, -2, (K = 1, Σ = -0.5:1.0:0.5, P = 1.5:1.0:1.5, F = 4.0:1.0:5.0, M = -5.0:1.0:5.0)), HundsCaseA_LinearMolecule(0.0, "A", 0, 0, 0, 0, 1, 1, 1/2, 1/2, 1/2, 9/2, 3/2, 5, -1, (K = 1, Σ = -0.5:1.0:0.5, P = 1.5:1.0:1.5, F = 4.0:1.0:5.0, M = -5.0:1.0:5.0)), HundsCaseA_LinearMolecule(0.0, "A", 0, 0, 0, 0, 1, 1, 1/2, 1/2, 1/2, 9/2, 3/2, 5, 0, (K = 1, Σ = -0.5:1.0:0.5, P = 1.5:1.0:1.5, F = 4.0:1.0:5.0, M = -5.0:1.0:5.0)), HundsCaseA_LinearMolecule(0.0, "A", 0, 0, 0, 0, 1, 1, 1/2, 1/2, 1/2, 9/2, 3/2, 5, 1, (K = 1, Σ = -0.5:1.0:0.5, P = 1.5:1.0:1.5, F = 4.0:1.0:5.0, M = -5.0:1.0:5.0)), HundsCaseA_LinearMolecule(0.0, "A", 0, 0, 0, 0, 1, 1, 1/2, 1/2, 1/2, 9/2, 3/2, 5, 2, (K = 1, Σ = -0.5:1.0:0.5, P = 1.5:1.0:1.5, F = 4.0:1.0:5.0, M = -5.0:1.0:5.0)), HundsCaseA_LinearMolecule(0.0, "A", 0, 0, 0, 0, 1, 1, 1/2, 1/2, 1/2, 9/2, 3/2, 5, 3, (K = 1, Σ = -0.5:1.0:0.5, P = 1.5:1.0:1.5, F = 4.0:1.0:5.0, M = -5.0:1.0:5.0)), HundsCaseA_LinearMolecule(0.0, "A", 0, 0, 0, 0, 1, 1, 1/2, 1/2, 1/2, 9/2, 3/2, 5, 4, (K = 1, Σ = -0.5:1.0:0.5, P = 1.5:1.0:1.5, F = 4.0:1.0:5.0, M = -5.0:1.0:5.0)), HundsCaseA_LinearMolecule(0.0, "A", 0, 0, 0, 0, 1, 1, 1/2, 1/2, 1/2, 9/2, 3/2, 5, 5, (K = 1, Σ = -0.5:1.0:0.5, P = 1.5:1.0:1.5, F = 4.0:1.0:5.0, M = -5.0:1.0:5.0))], ComplexF64[1.8426693600477864e-17 + 0.0im, 3.890609263924795e-15 + 0.0im, 2.3970106481669347e-14 + 0.0im, 4.0554067493064415e-14 + 0.0im, 2.048763876123814e-14 + 0.0im, 2.2105401985832132e-14 + 0.0im, 1.2593393201017e-14 + 0.0im, 8.792475142712803e-15 + 0.0im, 8.03636366525474e-12 + 0.0im, 6.426702742317415e-11 + 0.0im  …  1.1317289109897514e-15 + 0.0im, 1.4548589991116073e-14 + 0.0im, 7.211413417426996e-15 + 0.0im, 6.851217868266315e-15 + 0.0im, -1.0084638781098324e-16 + 0.0im, 2.1529000560330676e-16 + 0.0im, -5.848156571034068e- ...
